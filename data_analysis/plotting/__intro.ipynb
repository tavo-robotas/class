# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
info_1 = sns.load_dataset("flights")

# %%
sns.relplot(x='passengers', y='month', hue='year', data=info_1)

# %%
info_2 = sns.load_dataset('tips')

# %%
sns.relplot(x='time', y='tip', data=info_2, kind='line')
