# %% [markdown]
# An introduction to the concepts and applications in computer vision. Topics include: cameras and projection models, low-level image processing methods such as filtering and edge detection; mid-level vision topics such as segmentation and clustering; shape reconstruction from stereo, as well as high-level vision tasks such as object recognition, scene recognition, face detection and human motion categorization.
#
#
#
# # <code>**- Introduction**</code>
#     - Machine interaction with enviroment over image and video
#     - Historical Roots of Computer Vision
#     - Research field and latest achievements
#     - Prospects in science and career
#
# # <code>**- Image and camera**</code>
#
#    ***Image
#
#     - Image as a data structure and function
#     - RGB, HSV other spectrums and filters
#     - Destruction and recreation of 3'rd dimension
#
#    ***Camera
#
#     - Extrinsic, instrinsic parameters
#     - Perspective imaging
#     - Perspective PnP problem
#     - Stereo and epipolar geometry
#     - Calibration
#     - Image to image projection
#
# # <code>**- Shape desciptors**</code>
#     - Intuition
#     - Filters and filter as templates
#     - Edge detection (1D, 2D) and gradients
#     - Hough transform
#     - Fourier transform
#
# # <code>**- Features**</code>
#     - Intuition
#     - Corners
#     - Scale invariance
#     - SIFT descriptor
#
# # <code>**- Pose desciptors**</code>
#     - Intuition
#
# # <code>**- Machine learning**</code>
#     - Linear regression
#
# # <code>**- Artificial neural networks**</code>
#     - Intuition
#     - The neuron
#     - Activation function a.k.a transfer function
#         * Rectified Linear Unit (ReLU)
#         * Sigmoid
#     - Gradient Descent, understanding the mathematics behind GD
#     - Stochastic and Batch
#     - Backpropagation
#
# # <code>**- Convolutional neural networks (ConvNet)**</code>
#     - Intuition
#
# # <code>**- Object Detection**</code>
#     - Intuition
#     - SSD(Single shot detector)
#     - YOLO(You look only once)
#     - RCNN(Region based convolutional Neural Networks),
#
#
# # <code>**-  Generative adversarial networks (GANs)**</code>
#     - Intuition
#     - Image Creation with GANs
#
#     ## Build artificial artist
#
# # <code>**-  Face Detection**</code>
#     - Viola-Jones Algorithm
#     - Haar-like Features
#     - Integral Image
#     - Training Classifiers
#     - Adaptive Boosting
#     - Cascading
#     - Intuition
#
#     ## Build human emotion reader
#
# ## <code>**-  Prerequisites:**</code>
#
#     - Linear algebra intermediate (matrices, vectors and associated operations)
#     - Calculus intermediate (derivatives, partial derivatives)
#     - Probability(Gaussian/Normal distribution)
#     - Python or C++ basics
#     - OpenCV library*
#     - Numpy library
#     - Matplotlib library
#
#
# <code>**- * opencv build with cuda/cudnn for Nvidia GPU access in case you it on your machine**</code>
