# %% [markdown]
# <code>**Intro**</code><br/>
# 01 Python Installation -- not added <br/>
# 02 IDE Selection,VCODE Visual code -- not added<br/>
# 03 pip -- not added <br/>
# 04 Jupyter iPython Notebook -- not added<br/>
# 05 FAQ for notebook and additional resources<br/>
# 06 Git and Github Overview<br/>
#
# <code>**Object and Data Structure Basics**</code><br/>
# 11 Number<br/>
# 12 Strings<br/>
# 13 String formatting<br/>
# 14 Lists<br/>
# 15 Dictionaries<br/>
# 16 Tuples<br/>
# 17 Sets<br/>
#
# <code>**Comparison**</code><br/>
# 21 Comparison Operators
#
# <code>**Statements**</code><br/>
# 31 if, elif, else
#
# <code>**Context**</code><br/>
# 41 Context Managers
#
# <code>**Cycles**</code><br/>
# 51 For loops<br/>
# 52 While loops<br/>
# 53 Range<br/>
# 54 Lists comprehensions<br/>
#
# <code>**Functions and methods**</code><br/>
# 61 Methods<br/>
# 62 Functions<br/>
# 63 Lambda<br/>
# 64 Scope<br/>
#
# <code>**Object oriented programming**</code><br/>
# 71 Objects<br/>
# 72 Classes<br/>
# 73 Methods<br/>
# 74 Inheritance<br/>
# 75 Special methods<br/>
#
# <code>**Exceptions**</code><br/>
# 81 Errors and execptions handling<br/>
# 82 Except, finally<br/>
#
# <code>**Modules and packages**</code><br/>
# 91 Modules,packages and imports<br/>
#
# <code>**Built in functions**</code><br/>
# 101 Map<br/>
# 102 Reduce<br/>
# 103 Filter<br/>
# 104 Zip<br/>
# 105 Enumarate<br/>
# 106 All and any<br/>
# 107 Complex numbers --- not added<br/>
#
#
# <code>**Decorators**</code><br/>
# 111 Decorators<br/>
#
# <code>**Generators**</code><br/>
# 121 Generators and iterators<br/>
#
# <code>**Advances modules**</code><br/>
#
# -- not added ---
