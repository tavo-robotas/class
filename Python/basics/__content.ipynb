# %% [markdown]
# <code>**Intro**</code><br/>
# 01 Python Installation -- not added <br/>
# 02 IDE Selection,VCODE Visual code -- not added<br/>
# 03 pip -- not added <br/>
# 04 Jupyter iPython Notebook -- not added<br/>
# 05 FAQ for notebook and additional resources<br/>
# 06 Git and Github Overview<br/>
#
# <code>**Object and Data Structure Basics**</code><br/>
# 11 Number<br/>
# 12 Strings<br/>
# 13 String formatting<br/>
# 14 Lists<br/>
# 15 Dictionaries<br/>
# 16 Tuples<br/>
# 17 Sets<br/>
#
# <code>**Comparison**</code><br/>
# 21 Comparison Operators
#
# <code>**Statements**</code><br/>
# 31 if, elif, else
#
# <code>**Cycles**</code><br/>
# 41 For loops<br/>
# 42 While loops<br/>
# 43 Range<br/>
# 44 Lists comprehensions<br/>
#
# <code>**Functions and methods**</code><br/>
# 51 Methods<br/>
# 52 Functions<br/>
# 53 Lambda<br/>
# 54 Scope<br/>
#
# <code>**Object oriented programming**</code><br/>
# 61 Objects<br/>
# 62 Classes<br/>
# 63 Methods<br/>
# 64 Inheritance<br/>
# 65 Special methods<br/>
#
# <code>**Exceptions**</code><br/>
# 71 Errors and execptions handling<br/>
# 72 Except, finally<br/>
#
# <code>**Modules and packages**</code><br/>
# 81 Modules,packages and imports<br/>
#
# <code>**Built in functions**</code><br/>
# 91 Map<br/>
# 92 Reduce<br/>
# 93 Filter<br/>
# 94 Zip<br/>
# 95 Enumarate<br/>
# 96 All and any<br/>
# 97 Complex numbers --- not added<br/>
#
#
# <code>**Decorators**</code><br/>
# 101 Decorators<br/>
#
# <code>**Generators**</code><br/>
# 101 Generators and iterators<br/>
#
# <code>**Advances modules**</code><br/>
#
# -- not added ---
